# %%
import urllib2
import json
key = "c40a924af79efba5"
city = str('Glasgow')
url = 'http://api.wunderground.com/api/' + key + '/geolookup/forecast10day/q/UK/' + city + '.json'
f = urllib2.urlopen(url)
json_string = f.read()
parsed_json = json.loads(json_string)
print(parsed_json)
# Out:
# {u'forecast': {u'txt_forecast': {u'date': u'12:01 PM GMT', u'forecastday': [{u'title': u'Sunday', u'icon_url': u'http://icons.wxug.com/i/c/k/cloudy.gif', u'fcttext_metric': u'Generally cloudy. High 11C. Winds WSW at 15 to 30 km/h.', u'period': 0, u'pop': u'10', u'fcttext': u'Generally cloudy. High around 50F. Winds WSW at 10 to 20 mph.', u'icon': u'cloudy'}, {u'title': u'Sunday Night', u'icon_url': u'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif', u'fcttext_metric': u'Cloudy skies early, then partly cloudy after midnight. A few sprinkles possible. Low 4C. Winds SSW at 10 to 15 km/h.', u'period': 1, u'pop': u'10', u'fcttext': u'Cloudy early with some clearing expected late. A few sprinkles possible. Low near 40F. Winds S at 5 to 10 mph.', u'icon': u'nt_partlycloudy'}, {u'title': u'Monday', u'icon_url': u'http://icons.wxug.com/i/c/k/chancerain.gif', u'fcttext_metric': u'Cloudy skies with periods of light rain later in the day. High 8C. Winds light and variable. Chance of rain 60%.', 
# ...

# %%
print(parsed_json['forecast'], ['date'], ['high'])
# Out:
# ({u'txt_forecast': {u'date': u'12:01 PM GMT', u'forecastday': [{u'title': u'Sunday', u'icon_url': u'http://icons.wxug.com/i/c/k/cloudy.gif', u'fcttext_metric': u'Generally cloudy. High 11C. Winds WSW at 15 to 30 km/h.', u'period': 0, u'pop': u'10', u'fcttext': u'Generally cloudy. High around 50F. Winds WSW at 10 to 20 mph.', u'icon': u'cloudy'}, {u'title': u'Sunday Night', u'icon_url': u'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif', u'fcttext_metric': u'Cloudy skies early, then partly cloudy after midnight. A few sprinkles possible. Low 4C. Winds SSW at 10 to 15 km/h.', u'period': 1, u'pop': u'10', u'fcttext': u'Cloudy early with some clearing expected late. A few sprinkles possible. Low near 40F. Winds S at 5 to 10 mph.', u'icon': u'nt_partlycloudy'}, {u'title': u'Monday', u'icon_url': u'http://icons.wxug.com/i/c/k/chancerain.gif', u'fcttext_metric': u'Cloudy skies with periods of light rain later in the day. High 8C. Winds light and variable. Chance of rain 60%.', u'period': 2,
# ...
