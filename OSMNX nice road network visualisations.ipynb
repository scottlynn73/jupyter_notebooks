# %%
import osmnx as ox
from IPython.display import Image
# %matplotlib inline
ox.config(log_file=True, log_console=True, use_cache=True)

# %%
# configure the inline image display
img_folder = 'images'
extension = 'png'
size = 500
dpi = 300

# %%
place = 'Dunfermline'
point = (56.073776, -3.448697)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', dpi=dpi, default_width=3)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'Perth'
point = (56.395856, -3.432160)
fig, ax = ox.plot_figure_ground(point=point, network_type='all', filename=place, dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %% [markdown]
# Part III: Configure street width pixels
# OSMnx uses the highway OSM tag to ascribe street widths, in pixels. You can pass in a dictionary of street widths to override the default values. Any street type that does not appear as a key in the street widths dict falls back onto the default_width value.

# %%
street_widths = {'footway' : 0.5,
                 'steps' : 0.5,
                 'pedestrian' : 0.5,
                 'path' : 0.5,
                 'track' : 0.5,
                 'service' : 2,
                 'residential' : 3,
                 'primary' : 5,
                 'motorway' : 6}
place = 'perth_Custom'
point = (56.395856, -3.432160)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', street_widths=street_widths, dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)
